# %% [markdown]
# # GFS Machine Learning
# ## Lars Bogner, inf(19/20), Fr. Rupf

# %%
import ML_GFS_lib
import matplotlib.pyplot as plt

# %%
fit_func = ML_GFS_lib.FunktionAnlegen()
knn = ML_GFS_lib.NearestNeighbour()

# %% [markdown]
# ## Zuerst ein kNearestNeighbour Modell, welches mithilfe zufällig erstellter Daten 'trainiert' wurde.
# Die Daten sehen wie folgt aus: (x*y>.25:Blau else: Rot)

# %%
knn.plot_daten()

# %% [markdown]
# Nun werden zufällige Punkte ausgewählt und mit den k nächsten Punkten verglichen -> Einschätzung der Farbe des Modells

# %%
knn.test()

# %% [markdown]
# # Das zweite Beispiel: Das Anlegen einer Funktion
# Hierfür werden Punkte auf einer Parabel gewählt und gespeichert, jedoch haben sie ein zusätzl. Rauschen
#
# Die Punkte sehen wie folgt aus

# %%
fit_func.plot_daten()

# %% [markdown]
# Nun wird mithilfe von Polynomen eine ganzrat. Funktion vom Grad n angelegt

# %%
fit_func.trainieren(2) # Grad der Funktion
fit_func.plot_fkt_ganzrat_fkt_n()

# %% [markdown]
# Diese Funktion kann jetzt auch mithilfe eines Testsets überprüft werden. Unter einem Testset verstht man ähnliche Daten, welche jedoch nicht zum trainieren genutzt wurden.
#
# Wenn die Fehler (Abweichungen von d. ganzrat. Funkt.) berechnet werden und in einem Hisogramm dargestellt werden, sieht das wie folgt aus:
#
# Ebenfalls lässt sich der MSE (Mean Squared Error) ablesen (oben rechts)

# %%
fit_func.plot_test_der_fkt(80)
